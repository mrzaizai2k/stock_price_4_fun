# %%
import os
try:
    print(file_path)
except:
    file_path = os.path.abspath('')
    os.chdir(os.path.dirname(file_path))
    print(file_path)
# Out:
# /root/code_Bao/stock_price_4_fun/notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import stumpy
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import numpy.testing as npt
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from src.motif import MotifMatching, find_best_motifs
from src.Utils.utils import *
from vnstock import * #import all functions

# %%
motif_matching = MotifMatching('BCM', start_date="2023-09-11")

# %% [markdown]
# find the similar pattern in the same stock

# %%
motif_matching.find_similar_subseries_with_date(plot =True)
# Out:
# Similar Subsequence from 2023-09-11 to 2023-12-09 (Indices: 2023-03-08 to 2023-06-09)
# m: 65
# The distance score is 3.43
# ('2023-03-08', '2023-06-09', 3.4290107874057947)

# %% [markdown]
# find top pattern for the stock

# %%
motif_matching.plot_and_save_top_pattern()
# Out:
# Top 2 similar periods
# From 2023-09-11 to 2023-12-08: Distance = 0.0
# From 2023-03-08 to 2023-06-09: Distance = 3.429010787404616

# %% [markdown]
# find pattern with close and volume

# %%
motif_matching.plot_and_save_find_matching_series_multi_dim_with_date()
# Out:
# m: 65
# From 2023-03-08 00:00:00 to 2023-06-12 00:00:00
# nn_idx: [1255 1257]

# %%
results_dict = find_best_motifs()
results_dict
# Out:
# Pre filter stocks: ['ACB' 'AGG' 'BBC' 'BCM' 'BIC' 'BMI' 'BVH' 'CLL' 'CTG' 'DBD' 'EVF' 'FMC'
#  'GMD' 'HCM' 'HDB' 'HHV' 'IMP' 'KOS' 'LGC' 'MBB' 'NBB' 'PAN' 'STB' 'TCL'
#  'TDM' 'TIP' 'TNH' 'TV2' 'VCI' 'VGC' 'VNM' 'VPG' 'VRE']
# m: 22
# From 2020-11-02 00:00:00 to 2020-12-02 00:00:00
# nn_idx: [670 670]
# Ticker BCM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results_dict = find_best_motifs()
#       2 results_dict
#
# File ~/code_Bao/stock_price_4_fun/src/motif.py:266, in find_best_motifs(start_date, end_date, dimension_cols, nn_idx_threshold, distance_threshold, plot)
#     263 results_dict = {}  # Initialize an empty dictionary to store results
#     265 for ticker in unique_tickers:
# --> 266     motif = MotifMatching(symbol = ticker, start_date=start_date, end_date=end_date)
#     268     result, mps, start_date_index = motif.find_matching_series_multi_dim_with_date(
#     269                                                                         dimension_cols=dimension_cols,
#     270                                                                         nn_idx_threshold=nn_idx_threshold,
#     271                                                                         distance_threshold = distance_threshold,
#     272                                                                         )
#     274     # Check if the stock_name is not None
#
# File ~/code_Bao/stock_price_4_fun/src/motif.py:38, in MotifMatching.__init__(self, symbol, start_date, end_date)
#      32 if self.start_date is None:
#      33     self.start_date = (
#      34         datetime.strptime(self.end_date, "%Y-%m-%d") - timedelta(days=30)
#      35     ).strftime("%Y-%m-%d")
# ---> 38 self.dataframe = self.load_data()
#      39 self.filtered_data = self.filter_data()
#      40 self.m = len(self.filtered_data)
#
# File ~/code_Bao/stock_price_4_fun/src/motif.py:43, in MotifMatching.load_data(self)
#      42 def load_data(self):
# ---> 43     data = stock_historical_data(self.symbol, "2007-01-01" ,self.end_date, "1D", type = self.type)
#      44     data = convert_data_type(data, [self.time_col], self.float_cols, self.cat_cols)
#      45     return data
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/vnstock/technical.py:21, in stock_historical_data(symbol, start_date, end_date, resolution, type, beautify, headers)
#       4 def stock_historical_data (symbol='TCB', start_date='2023-06-01', end_date='2023-06-17', resolution='1D', type='stock', beautify=True, headers=entrade_headers): # DNSE source (will be published on vnstock)
#       5     """
#       6     Get historical price data from entrade.com.vn. The unit price is VND.
#       7     Parameters:
#    (...)
#      19         | YYYY-mm-dd  | xxxx | xxxx | xxx | xxxxx | xxxxxx |
#      20     """
# ---> 21     df = ohlc_data(symbol, start_date, end_date, resolution, type, beautify, headers)
#      22     return df
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/vnstock/technical.py:54, in ohlc_data(symbol, start_date, end_date, resolution, type, beautify, headers)
#      52         print("Data is limited to the last 90 days for all resolution in minutes", "\n")
#      53 url = f"https://services.entrade.com.vn/chart-api/v2/ohlcs/{type}?from={from_timestamp}&to={to_timestamp}&symbol={symbol}&resolution={resolution}"
# ---> 54 response = requests.request("GET", url, headers=headers)
#      56 if response.status_code == 200:
#      57     response_data = response.json()
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/code_Bao/stock_price_4_fun/venv/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1303, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1299     if flags != 0:
#    1300         raise ValueError(
#    1301           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302           self.__class__)
# -> 1303     return self.read(nbytes, buffer)
#    1304 else:
#    1305     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1159, in SSLSocket.read(self, len, buffer)
#    1157 try:
#    1158     if buffer is not None:
# -> 1159         return self._sslobj.read(len, buffer)
#    1160     else:
#    1161         return self._sslobj.read(len)
#
# KeyboardInterrupt:
