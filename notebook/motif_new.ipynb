# %%
import os
try:
    print(file_path)
except:
    file_path = os.path.abspath('')
    os.chdir(os.path.dirname(file_path))
    print(file_path)
# Out:
# /root/code_Bao/stock_price_4_fun/notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import stumpy
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import numpy.testing as npt
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from src.motif import MotifMatching
from src.utils import *
from vnstock import * #import all functions

# %%
motif_matching = MotifMatching('VNINDEX', start_date="2023-09-11")

# %% [markdown]
# find the similar pattern in the same stock

# %%
motif_matching.find_similar_subseries_with_date(plot =True)
# Out:
# Similar Subsequence from 2023-09-11 to 2023-11-09 (Indices: 2022-09-26 to 2022-11-24)
# m: 44
# The distance score is 2.99
# ('2022-09-26', '2022-11-24', 2.989330391774005)

# %% [markdown]
# find top pattern for the stock

# %%
motif_matching.find_top_pattern()
# Out:
# Top 3 similar periods
# From 2023-09-11 to 2023-11-09: Distance = 0.0
# From 2022-09-26 to 2022-11-24: Distance = 2.9893303917744873
# From 2022-03-29 to 2022-06-01: Distance = 3.0226709701489387

# %% [markdown]
# find pattern with close and volume

# %%
motif_matching.find_matching_series_multi_dim_with_date(motif_matching.dataframe)
# Out:
# m: 44
# Ticker: VNINDEX
# From 2022-09-26 00:00:00 to 2022-11-25 00:00:00
# nn_idx: [566 439]
# ('VNINDEX', array([566.        , 439.        ,   3.80315672]))

# %%
results_dict = motif_matching.find_best_motifs()
results_dict
# Out:
# ['ACB' 'AGG' 'BCM' 'BIC' 'BMI' 'BVH' 'CLL' 'CNG' 'CTG' 'DBD' 'FMC' 'GMD'
#  'HCM' 'HDB' 'HHV' 'IMP' 'KOS' 'LGC' 'MBB' 'NBB' 'PAN' 'S4A' 'STB' 'TCL'
#  'TDM' 'TIP' 'TNH' 'TV2' 'VCI' 'VFG' 'VGC' 'VNM' 'VPG' 'VRE']
# m: 44
# Ticker: BIC
# From 2013-11-28 00:00:00 to 2014-02-10 00:00:00
# nn_idx: [426 426]
# m: 44
# Ticker: BVH
# From 2019-06-26 00:00:00 to 2019-08-27 00:00:00
# nn_idx: [1810 1809]
# m: 44
# Ticker: DBD
# From 2021-06-15 00:00:00 to 2021-08-16 00:00:00
# nn_idx: [1096 1096]
# m: 44
# Ticker: KOS
# From 2021-05-12 00:00:00 to 2021-07-13 00:00:00
# nn_idx: [847 846]
# m: 44
# Ticker: MBB
# From 2020-12-16 00:00:00 to 2021-02-24 00:00:00
# nn_idx: [2184 2184]
# m: 44
# Ticker: NBB
# From 2021-07-23 00:00:00 to 2021-09-27 00:00:00
# nn_idx: [2332 2332]
# m: 44
# Ticker: S4A
# From 2019-12-30 00:00:00 to 2020-03-09 00:00:00
# nn_idx: [901 901]
# m: 44
# Ticker: TDM
# From 2016-04-01 00:00:00 to 2016-06-07 00:00:00
# nn_idx: [0 0]
# m: 44
# Ticker: TIP
# From 2019-12-16 00:00:00 to 2020-02-24 00:00:00
# nn_idx: [885 885]
# m: 44
# Ticker: TNH
# From 2022-07-15 00:00:00 to 2022-09-19 00:00:00
# nn_idx: [378 377]
# m: 44
# Ticker: TV2
# From 2015-01-15 00:00:00 to 2015-03-26 00:00:00
# nn_idx: [705 704]
# m: 44
# Ticker: VGC
# From 2022-01-24 00:00:00 to 2022-04-01 00:00:00
# nn_idx: [1561 1561]
# {'BIC': array([426.       , 426.       ,   4.6624691]),
#  'BVH': array([1810.        , 1809.        ,    4.01727711]),
#  'DBD': array([1096.        , 1096.        ,    3.66594682]),
#  'KOS': array([847.        , 846.        ,   3.18822407]),
#  'MBB': array([2184.        , 2184.        ,    4.31118795]),
#  'NBB': array([2332.        , 2332.        ,    3.15007691]),
#  'S4A': array([901.        , 901.        ,   3.31256812]),
#  'TDM': array([0.        , 0.        , 2.51606041]),
#  'TIP': array([885.        , 885.        ,   3.66448833]),
#  'TNH': array([378.       , 377.       ,   3.7073606]),
#  'TV2': array([705.        , 704.        ,   3.54888243]),
#  'VGC': array([1561.        , 1561.        ,    4.35262798])}
