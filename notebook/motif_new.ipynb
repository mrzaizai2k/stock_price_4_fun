# %%
import os
try:
    print(file_path)
except:
    file_path = os.path.abspath('')
    os.chdir(os.path.dirname(file_path))
    print(file_path)
# Out:
# /root/code_Bao/stock_price_4_fun/notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import stumpy
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import numpy.testing as npt
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from src.motif import MotifMatching, find_best_motifs
from src.Utils.utils import *
from vnstock import * #import all functions

# %%
motif_matching = MotifMatching('VNINDEX', start_date="2023-09-11")

# %% [markdown]
# find the similar pattern in the same stock

# %%
motif_matching.find_similar_subseries_with_date(plot =True)
# Out:
# Similar Subsequence from 2023-09-11 to 2023-11-10 (Indices: 2022-09-26 to 2022-11-25)
# m: 45
# The distance score is 3.01
# ('2022-09-26', '2022-11-25', 3.013317742446778)

# %% [markdown]
# find top pattern for the stock

# %%
motif_matching.find_top_pattern()
# Out:
# Top 3 similar periods
# From 2023-09-11 to 2023-11-10: Distance = 3.1531012012807765e-06
# From 2022-09-26 to 2022-11-25: Distance = 3.0133177424483697
# From 2022-03-29 to 2022-06-02: Distance = 3.0437679369154758

# %% [markdown]
# find pattern with close and volume

# %%
ticker, result = motif_matching.find_matching_series_multi_dim_with_date()
# Out:
# m: 45
# Ticker: VNINDEX
# From 2022-09-26 00:00:00 to 2022-11-28 00:00:00
# nn_idx: [566 439]

# %%
results_dict = find_best_motifs()
results_dict
# Out:
# Pre filter stocks: ['ACB' 'AGG' 'BCM' 'BIC' 'BMI' 'BVH' 'CLL' 'CNG' 'CTG' 'CTR' 'DBD' 'FMC'
#  'GMD' 'HCM' 'HDB' 'HHV' 'IMP' 'KOS' 'LGC' 'MBB' 'NBB' 'PAN' 'S4A' 'STB'
#  'TCL' 'TDM' 'TIP' 'TNH' 'TV2' 'VCI' 'VGC' 'VNM' 'VPG' 'VRE']
# m: 23
# Ticker: BCM
# From 2020-03-06 00:00:00 to 2020-04-09 00:00:00
# nn_idx: [510 510]
# m: 23
# Ticker: CLL
# From 2022-06-02 00:00:00 to 2022-07-05 00:00:00
# nn_idx: [1971 1971]
# m: 23
# Ticker: HHV
# From 2023-04-03 00:00:00 to 2023-05-09 00:00:00
# nn_idx: [1812 1812]
# m: 23
# Ticker: NBB
# From 2015-04-13 00:00:00 to 2015-05-20 00:00:00
# nn_idx: [761 761]
# m: 23
# Ticker: TIP
# From 2023-06-09 00:00:00 to 2023-07-12 00:00:00
# nn_idx: [1754 1754]
# m: 23
# Ticker: VCI
# From 2020-03-16 00:00:00 to 2020-04-17 00:00:00
# nn_idx: [670 671]
# {'BCM': ['2020-03-06', '2020-04-09', 2.429460982688025],
#  'CLL': ['2022-06-02', '2022-07-05', 2.672515328846937],
#  'HHV': ['2023-04-03', '2023-05-09', 2.5866151979792105],
#  'NBB': ['2015-04-13', '2015-05-20', 2.681534942928455],
#  'TIP': ['2023-06-09', '2023-07-12', 2.879199450738005],
#  'VCI': ['2020-03-16', '2020-04-17', 2.485867112343164]}
