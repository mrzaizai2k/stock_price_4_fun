# %%
import os
try:
    print(file_path)
except:
    file_path = os.path.abspath('')
    os.chdir(os.path.dirname(file_path))
    print(file_path)
# Out:
# /root/code_Bao/stock_price_4_fun/notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import stumpy
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import numpy.testing as npt
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from src.motif import MotifMatching, find_best_motifs
from src.Utils.utils import *
from vnstock import * #import all functions

# %%
motif_matching = MotifMatching('VNINDEX', start_date="2023-09-11")

# %% [markdown]
# find the similar pattern in the same stock

# %%
motif_matching.find_similar_subseries_with_date(plot =True)
# Out:
# Similar Subsequence from 2023-09-11 to 2023-12-09 (Indices: 2022-03-29 to 2022-06-30)
# m: 65
# The distance score is 4.60
# ('2022-03-29', '2022-06-30', 4.5983186700241765)

# %% [markdown]
# find top pattern for the stock

# %%
motif_matching.plot_and_save_top_pattern()
# Out:
# Top 3 similar periods
# From 2023-09-11 to 2023-12-08: Distance = 2.648469193625204e-06
# From 2022-03-29 to 2022-06-30: Distance = 4.598318670025331
# From 2022-09-15 to 2022-12-14: Distance = 4.751172587303522

# %% [markdown]
# find pattern with close and volume

# %%
ticker, result = motif_matching.find_matching_series_multi_dim_with_date()
# Out:
# m: 65
# Ticker: VNINDEX
# From 2022-03-29 00:00:00 to 2022-07-01 00:00:00
# nn_idx: [442 439]

# %%
results_dict = find_best_motifs()
results_dict
# Out:
# Pre filter stocks: ['ACB' 'AGG' 'BBC' 'BCM' 'BIC' 'BMI' 'BVH' 'CLL' 'CTG' 'DBD' 'EVF' 'FMC'
#  'GMD' 'HCM' 'HDB' 'HHV' 'IMP' 'KOS' 'LGC' 'MBB' 'NBB' 'PAN' 'STB' 'TCL'
#  'TDM' 'TIP' 'TNH' 'TV2' 'VCI' 'VGC' 'VNM' 'VPG' 'VRE']
# m: 22
# Ticker: BCM
# From 2020-11-02 00:00:00 to 2020-12-02 00:00:00
# nn_idx: [670 670]
# m: 22
# Ticker: MBB
# From 2022-12-09 00:00:00 to 2023-01-10 00:00:00
# nn_idx: [2679 2679]
# m: 22
# Ticker: PAN
# From 2013-01-16 00:00:00 to 2013-02-22 00:00:00
# nn_idx: [210 210]
# m: 22
# Ticker: TDM
# From 2017-07-17 00:00:00 to 2017-08-16 00:00:00
# nn_idx: [323 325]
# m: 22
# Ticker: TIP
# From 2023-06-28 00:00:00 to 2023-07-28 00:00:00
# nn_idx: [1767 1767]
# {'BCM': ['2020-11-02', '2020-12-02', 1.8898082299622967],
#  'MBB': ['2022-12-09', '2023-01-10', 2.6527653255485575],
#  'PAN': ['2013-01-16', '2013-02-22', 2.001509382132339],
#  'TDM': ['2017-07-17', '2017-08-16', 2.666180136144041],
#  'TIP': ['2023-06-28', '2023-07-28', 2.337569237900915]}
